# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('Data Sheet for Interns.xlsx',sheet_name='PMP',header=1)

# %%
df.shape
# Out:
# (273, 6)

# %%
df.head()
# Out:
#   2020-11-01 00:00:00 Councellor Name Course Type Fees Received Fees Total  \
# 0          2020-11-01         Vineeta         PMP          6750       6750
# 1          2020-11-01         Vineeta         PMP          7500       7500
# 2          2020-11-01         Vineeta         PMP          3500       7500
# 3          2020-11-01         Vineeta         PMP          7500       7500
# 4          2020-11-01           Tarun         PMP          7500       7500
#
#   Fees Pending
# 0            o
# 1            0
# 2         4000
# 3            0
# 4            0

# %%
df = df.rename(columns={df.columns[0]: 'Month'})
df
# Out:
#          Month Councellor Name      Course Type    Fees Received Fees Total  \
# 0   2020-11-01         Vineeta              PMP             6750       6750
# 1   2020-11-01         Vineeta              PMP             7500       7500
# 2   2020-11-01         Vineeta              PMP             3500       7500
# 3   2020-11-01         Vineeta              PMP             7500       7500
# 4   2020-11-01           Tarun              PMP             7500       7500
# ..         ...             ...              ...              ...        ...
# 268 2021-07-01         Vineeta              PMP              PMP      14900
# 269 2021-07-01         Vineeta  BA With [python  BA With [python      13500
# 270 2021-07-01         Vineeta             IFRS             IFRS      15000
# 271 2021-07-01         Vineeta        PMP+Agile              PMP      14900
# 272 2021-07-01             NaN              NaN             ifrs      15000
#
#     Fees Pending
# 0              o
# 1              0
# 2           4000
# 3              0
# 4              0
# ..           ...
# 268        14900
# 269        13500
# 270        15000
# 271        14900
# 272        15000
#
# [273 rows x 6 columns]

# %%
df.rename({'Councellor Name': 'Counsellor Name'}, axis=1, inplace=True)
df
# Out:
#          Month Counsellor Name      Course Type    Fees Received Fees Total  \
# 0   2020-11-01         Vineeta              PMP             6750       6750
# 1   2020-11-01         Vineeta              PMP             7500       7500
# 2   2020-11-01         Vineeta              PMP             3500       7500
# 3   2020-11-01         Vineeta              PMP             7500       7500
# 4   2020-11-01           Tarun              PMP             7500       7500
# ..         ...             ...              ...              ...        ...
# 268 2021-07-01         Vineeta              PMP              PMP      14900
# 269 2021-07-01         Vineeta  BA With [python  BA With [python      13500
# 270 2021-07-01         Vineeta             IFRS             IFRS      15000
# 271 2021-07-01         Vineeta        PMP+Agile              PMP      14900
# 272 2021-07-01             NaN              NaN             ifrs      15000
#
#     Fees Pending
# 0              o
# 1              0
# 2           4000
# 3              0
# 4              0
# ..           ...
# 268        14900
# 269        13500
# 270        15000
# 271        14900
# 272        15000
#
# [273 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Month               0
# Counsellor Name    44
# Course Type        44
# Fees Received      44
# Fees Total         43
# Fees Pending       42
# dtype: int64

# %%
df.dropna(how='all',inplace=True)

# %%
df.isnull().sum()
# Out:
# Month               0
# Counsellor Name    44
# Course Type        44
# Fees Received      44
# Fees Total         43
# Fees Pending       42
# dtype: int64

# %%
df[df['Counsellor Name'].isna()]
# Out:
#          Month Counsellor Name Course Type Fees Received Fees Total  \
# 12  2020-11-01             NaN         NaN           NaN        NaN
# 13  2020-11-01             NaN         NaN           NaN        NaN
# 14  2020-11-01             NaN         NaN           NaN        NaN
# 27  2020-12-01             NaN         NaN           NaN        NaN
# 28  2020-12-01             NaN         NaN           NaN        NaN
# 29  2020-12-01             NaN         NaN           NaN        NaN
# 30  2020-12-01             NaN         NaN           NaN        NaN
# 31  2020-12-01             NaN         NaN           NaN        NaN
# 54  2021-01-01             NaN         NaN           NaN        NaN
# 55  2021-01-01             NaN         NaN           NaN        NaN
# 56  2021-01-01             NaN         NaN           NaN        NaN
# 57  2021-01-01             NaN         NaN           NaN        NaN
# 58  2021-01-01             NaN         NaN           NaN        NaN
# 90  2021-02-01             NaN         NaN           NaN        NaN
# 91  2021-02-01             NaN         NaN           NaN        NaN
# 92  2021-02-01             NaN         NaN           NaN        NaN
# 93  2021-02-01             NaN         NaN           NaN        NaN
# 94  2021-02-01             NaN         NaN           NaN        NaN
# 95  2021-02-01             NaN         NaN           NaN        NaN
# 96  2021-02-01             NaN         NaN           NaN        NaN
# 97  2021-02-01             NaN         NaN           NaN        NaN
# 98  2021-02-01             NaN         NaN           NaN        NaN
# 99  2021-02-01             NaN         NaN           NaN        NaN
# 124 2021-03-01             NaN         NaN           NaN        NaN
# 125 2021-03-01             NaN         NaN           NaN        NaN
# 126 2021-03-01             NaN         NaN           NaN        NaN
# 127 2021-03-01             NaN         NaN           NaN        NaN
# 128 2021-03-01             NaN         NaN           NaN        NaN
# 129 2021-03-01             NaN         NaN           NaN        NaN
# 130 2021-03-01             NaN         NaN           NaN        NaN
# 154 2021-04-01             NaN         NaN           NaN        NaN
# 155 2021-04-01             NaN         NaN           NaN        NaN
# 156 2021-04-01             NaN         NaN           NaN        NaN
# 157 2021-04-01             NaN         NaN           NaN        NaN
# 158 2021-04-01             NaN         NaN           NaN        NaN
# 159 2021-04-01             NaN         NaN           NaN        NaN
# 160 2021-04-01             NaN         NaN           NaN        NaN
# 161 2021-04-01             NaN         NaN           NaN        NaN
# 162 2021-04-01             NaN         NaN           NaN        NaN
# 173 2021-05-01             NaN         NaN           NaN        NaN
# 198 2021-05-01             NaN         NaN           NaN        NaN
# 199 2021-05-01             NaN         NaN           NaN        NaN
# 251 2021-07-01             NaN         NaN           NaN        NaN
# 272 2021-07-01             NaN         NaN          ifrs      15000
#
#     Fees Pending
# 12             0
# 13             0
# 14           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# 30           NaN
# 31           NaN
# 54           NaN
# 55           NaN
# 56           NaN
# 57           NaN
# 58           NaN
# 90           NaN
# 91           NaN
# 92           NaN
# 93           NaN
# 94           NaN
# 95           NaN
# 96           NaN
# 97           NaN
# 98           NaN
# 99           NaN
# 124          NaN
# 125          NaN
# 126          NaN
# 127          NaN
# 128          NaN
# 129          NaN
# 130          NaN
# 154          NaN
# 155          NaN
# 156          NaN
# 157          NaN
# 158          NaN
# 159          NaN
# 160          NaN
# 161          NaN
# 162          NaN
# 173          NaN
# 198          NaN
# 199          NaN
# 251          NaN
# 272        15000

# %%
df.dropna(subset=['Counsellor Name','Course Type','Fees Received','Fees Total','Fees Pending'],how='all',inplace=True)
df.isnull().sum()
# Out:
# Month              0
# Counsellor Name    3
# Course Type        3
# Fees Received      3
# Fees Total         2
# Fees Pending       1
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#          Month Counsellor Name Course Type Fees Received Fees Total  \
# 12  2020-11-01             NaN         NaN           NaN        NaN
# 13  2020-11-01             NaN         NaN           NaN        NaN
# 15  2020-12-01         Vineeta         PMP         12000      12000
# 200 2021-06-01      Consultant  Consultant           NaN         IT
# 272 2021-07-01             NaN         NaN          ifrs      15000
#
#     Fees Pending
# 12             0
# 13             0
# 15           NaN
# 200   Consultant
# 272        15000

# %%
df.dropna(subset=['Course Type','Fees Received','Fees Total'],how='all',inplace=True)
df[df.isna().any(axis=1)]
# Out:
#          Month Counsellor Name Course Type Fees Received Fees Total  \
# 15  2020-12-01         Vineeta         PMP         12000      12000
# 200 2021-06-01      Consultant  Consultant           NaN         IT
# 272 2021-07-01             NaN         NaN          ifrs      15000
#
#     Fees Pending
# 15           NaN
# 200   Consultant
# 272        15000

# %%
IsDigit=pd.DataFrame(df['Fees Received'].str.isdigit())
notDigit=df[IsDigit['Fees Received']==False]
notDigit
# Out:
#          Month  Counsellor Name      Course Type    Fees Received  \
# 59  2021-02-01       Consultant       Consultant       Consultant
# 60  2021-02-01  Councellor Name      Course Type    Fees Received
# 100 2021-03-01       Consultant       Consultant       Consultant
# 101 2021-03-01  Councellor Name      Course Type    Fees Received
# 131 2021-04-01  Councellor Name      Course Type  Standard Course
# ..         ...              ...              ...              ...
# 268 2021-07-01          Vineeta              PMP              PMP
# 269 2021-07-01          Vineeta  BA With [python  BA With [python
# 270 2021-07-01          Vineeta             IFRS             IFRS
# 271 2021-07-01          Vineeta        PMP+Agile              PMP
# 272 2021-07-01              NaN              NaN             ifrs
#
#         Fees Total  Fees Pending
# 59      Consultant    Consultant
# 60      Total Fees  Fees Pending
# 100     Consultant    Consultant
# 101     Total Fees  Fees Pending
# 131  Fees Received    Total Fees
# ..             ...           ...
# 268          14900         14900
# 269          13500         13500
# 270          15000         15000
# 271          14900         14900
# 272          15000         15000
#
# [132 rows x 6 columns]

# %%
df=pd.read_excel('PMP_cleaned Copy.xlsx')

# %%
df
# Out:
#      Unnamed: 0      Month Counsellor Name      Course Type Fees Received  \
# 0             0 2020-11-01         Vineeta              PMP          6750
# 1             1 2020-11-01         Vineeta              PMP          7500
# 2             2 2020-11-01         Vineeta              PMP          3500
# 3             3 2020-11-01         Vineeta              PMP          7500
# 4             4 2020-11-01           Tarun              PMP          7500
# ..          ...        ...             ...              ...           ...
# 225         268 2021-07-01         Vineeta              PMP         14900
# 226         269 2021-07-01         Vineeta  BA With [python         13500
# 227         270 2021-07-01         Vineeta             IFRS         15000
# 228         271 2021-07-01         Vineeta        PMP+Agile         14900
# 229         272 2021-07-01             NaN              NaN         15000
#
#     Fees Total Fees Pending
# 0         6750            o
# 1         7500            0
# 2         7500         4000
# 3         7500            0
# 4         7500            0
# ..         ...          ...
# 225      14900          NaN
# 226      13500          NaN
# 227      15000          NaN
# 228      14900          NaN
# 229      15000          NaN
#
# [230 rows x 7 columns]

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Month                0
# Counsellor Name      1
# Course Type          1
# Fees Received        0
# Fees Total           0
# Fees Pending       130
# dtype: int64

# %%
df[df['Counsellor Name'].isna()]
# Out:
#          Month Counsellor Name Course Type Fees Received Fees Total  \
# 229 2021-07-01             NaN         NaN         15000      15000
#
#     Fees Pending
# 229          NaN

# %%
df['Counsellor Name'].fillna(value='No Counsellor',inplace=True)

# %%
df['Course Type'].fillna(value='Analytics',inplace=True)
df.isnull().sum()
# Out:
# Month                0
# Counsellor Name      0
# Course Type          0
# Fees Received        0
# Fees Total           0
# Fees Pending       130
# dtype: int64

# %%
IsDigit=pd.DataFrame(df['Fees Received'].str.isdigit())
notDigit=df[IsDigit['Fees Received']==False]
notDigit
# Out:
#          Month  Counsellor Name  Course Type  Fees Received  Fees Total  \
# 46  2021-02-01       Consultant   Consultant     Consultant  Consultant
# 47  2021-02-01  Councellor Name  Course Type  Fees Received  Total Fees
# 77  2021-03-01       Consultant   Consultant     Consultant  Consultant
# 78  2021-03-01  Councellor Name  Course Type  Fees Received  Total Fees
# 101 2021-04-01  Councellor Name  Course Type  Fees Received  Total Fees
# 124 2021-05-01       Consultant   Consultant     Consultant  Consultant
# 125 2021-05-01  Councellor Name  Course Type  Fees Received  Total Fees
# 158 2021-06-01       Consultant   Consultant             IT  Consultant
# 159 2021-06-01  Councellor Name  Course Type  Fees Received  Total Fees
# 200 2021-07-01       Consultant   Consultant             IT  Consultant
# 201 2021-07-01  Councellor Name  Course Type  Fees Received  Total Fees
#
#      Fees Pending
# 46     Consultant
# 47   Fees Pending
# 77     Consultant
# 78   Fees Pending
# 101           NaN
# 124           NaN
# 125           NaN
# 158           NaN
# 159           NaN
# 200           NaN
# 201           NaN

# %%
df.drop(notDigit.index,inplace=True)
df
# Out:
#          Month Counsellor Name      Course Type Fees Received Fees Total  \
# 0   2020-11-01         Vineeta              PMP          6750       6750
# 1   2020-11-01         Vineeta              PMP          7500       7500
# 2   2020-11-01         Vineeta              PMP          3500       7500
# 3   2020-11-01         Vineeta              PMP          7500       7500
# 4   2020-11-01           Tarun              PMP          7500       7500
# ..         ...             ...              ...           ...        ...
# 225 2021-07-01         Vineeta              PMP         14900      14900
# 226 2021-07-01         Vineeta  BA With [python         13500      13500
# 227 2021-07-01         Vineeta             IFRS         15000      15000
# 228 2021-07-01         Vineeta        PMP+Agile         14900      14900
# 229 2021-07-01   No Counsellor        Analytics         15000      15000
#
#     Fees Pending
# 0              o
# 1              0
# 2           4000
# 3              0
# 4              0
# ..           ...
# 225          NaN
# 226          NaN
# 227          NaN
# 228          NaN
# 229          NaN
#
# [219 rows x 6 columns]

# %%
df['Fees Received']=df['Fees Received'].astype('int64')

# %%
df['Fees Total']=df['Fees Total'].astype('int64')

# %%
df['FeesPending'] = df['Fees Total'] - df['Fees Received']
df
# Out:
#          Month Counsellor Name      Course Type  Fees Received  Fees Total  \
# 0   2020-11-01         Vineeta              PMP           6750        6750
# 1   2020-11-01         Vineeta              PMP           7500        7500
# 2   2020-11-01         Vineeta              PMP           3500        7500
# 3   2020-11-01         Vineeta              PMP           7500        7500
# 4   2020-11-01           Tarun              PMP           7500        7500
# ..         ...             ...              ...            ...         ...
# 225 2021-07-01         Vineeta              PMP          14900       14900
# 226 2021-07-01         Vineeta  BA With [python          13500       13500
# 227 2021-07-01         Vineeta             IFRS          15000       15000
# 228 2021-07-01         Vineeta        PMP+Agile          14900       14900
# 229 2021-07-01   No Counsellor        Analytics          15000       15000
#
#     Fees Pending  FeesPending
# 0              o            0
# 1              0            0
# 2           4000         4000
# 3              0            0
# 4              0            0
# ..           ...          ...
# 225          NaN            0
# 226          NaN            0
# 227          NaN            0
# 228          NaN            0
# 229          NaN            0
#
# [219 rows x 7 columns]

# %%
df.drop(['Fees Pending'],axis=1,inplace=True)
df
# Out:
#          Month Counsellor Name      Course Type  Fees Received  Fees Total  \
# 0   2020-11-01         Vineeta              PMP           6750        6750
# 1   2020-11-01         Vineeta              PMP           7500        7500
# 2   2020-11-01         Vineeta              PMP           3500        7500
# 3   2020-11-01         Vineeta              PMP           7500        7500
# 4   2020-11-01           Tarun              PMP           7500        7500
# ..         ...             ...              ...            ...         ...
# 225 2021-07-01         Vineeta              PMP          14900       14900
# 226 2021-07-01         Vineeta  BA With [python          13500       13500
# 227 2021-07-01         Vineeta             IFRS          15000       15000
# 228 2021-07-01         Vineeta        PMP+Agile          14900       14900
# 229 2021-07-01   No Counsellor        Analytics          15000       15000
#
#      FeesPending
# 0              0
# 1              0
# 2           4000
# 3              0
# 4              0
# ..           ...
# 225            0
# 226            0
# 227            0
# 228            0
# 229            0
#
# [219 rows x 6 columns]

# %%
df['Month'] = pd.to_datetime(df['Month'],format='%m%Y')

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#          Month Counsellor Name      Course Type  Fees Received  Fees Total  \
# 0   2020-11-01         Vineeta              PMP           6750        6750
# 1   2020-11-01         Vineeta              PMP           7500        7500
# 2   2020-11-01         Vineeta              PMP           3500        7500
# 3   2020-11-01         Vineeta              PMP           7500        7500
# 4   2020-11-01           Tarun              PMP           7500        7500
# ..         ...             ...              ...            ...         ...
# 214 2021-07-01         Vineeta              PMP          14900       14900
# 215 2021-07-01         Vineeta  BA With [python          13500       13500
# 216 2021-07-01         Vineeta             IFRS          15000       15000
# 217 2021-07-01         Vineeta        PMP+Agile          14900       14900
# 218 2021-07-01   No Counsellor        Analytics          15000       15000
#
#      FeesPending
# 0              0
# 1              0
# 2           4000
# 3              0
# 4              0
# ..           ...
# 214            0
# 215            0
# 216            0
# 217            0
# 218            0
#
# [219 rows x 6 columns]

# %%
df.shape
# Out:
# (219, 6)

# %%
df.isnull().sum()
# Out:
# Month              0
# Counsellor Name    0
# Course Type        0
# Fees Received      0
# Fees Total         0
# FeesPending        0
# dtype: int64

# %%
df.dtypes
# Out:
# Month              datetime64[ns]
# Counsellor Name            object
# Course Type                object
# Fees Received               int64
# Fees Total                  int64
# FeesPending                 int64
# dtype: object

# %%
df.to_excel("PMP_cleaned.xlsx")

# %%
df
# Out:
#          Month Counsellor Name      Course Type  Fees Received  Fees Total  \
# 0   2020-11-01         Vineeta              PMP           6750        6750
# 1   2020-11-01         Vineeta              PMP           7500        7500
# 2   2020-11-01         Vineeta              PMP           3500        7500
# 3   2020-11-01         Vineeta              PMP           7500        7500
# 4   2020-11-01           Tarun              PMP           7500        7500
# ..         ...             ...              ...            ...         ...
# 214 2021-07-01         Vineeta              PMP          14900       14900
# 215 2021-07-01         Vineeta  BA With [python          13500       13500
# 216 2021-07-01         Vineeta             IFRS          15000       15000
# 217 2021-07-01         Vineeta        PMP+Agile          14900       14900
# 218 2021-07-01   No Counsellor        Analytics          15000       15000
#
#      FeesPending
# 0              0
# 1              0
# 2           4000
# 3              0
# 4              0
# ..           ...
# 214            0
# 215            0
# 216            0
# 217            0
# 218            0
#
# [219 rows x 6 columns]
