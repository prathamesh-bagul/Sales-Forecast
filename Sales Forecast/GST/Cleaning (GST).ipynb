# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('Data Sheet for Interns.xlsx',sheet_name='GST',header=1)

# %%
df.shape
# Out:
# (1297, 6)

# %%
df.head()
# Out:
#                  Month   Owner Course Name Fees Received Fees Total  \
# 0  2020-04-01 00:00:00   Pooja         NaN          7500       7500
# 1  2020-04-01 00:00:00  Deepak         NaN          8550       8550
# 2  2020-04-01 00:00:00   Pooja         NaN          6750       6750
# 3  2020-04-01 00:00:00  Deepak         NaN          8550       8550
# 4  2020-04-01 00:00:00  Deepak         NaN          5000       5000
#
#   Fees Pending
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
#df.dropna(how='all',inplace=True)

# %%
df.rename({'Owner': 'Counsellor Name'}, axis=1, inplace=True)
df
# Out:
#                     Month Counsellor Name Course Name Fees Received  \
# 0     2020-04-01 00:00:00           Pooja         NaN          7500
# 1     2020-04-01 00:00:00          Deepak         NaN          8550
# 2     2020-04-01 00:00:00           Pooja         NaN          6750
# 3     2020-04-01 00:00:00          Deepak         NaN          8550
# 4     2020-04-01 00:00:00          Deepak         NaN          5000
# ...                   ...             ...         ...           ...
# 1292  2021-07-01 00:00:00             NaN         NaN           NaN
# 1293  2021-07-01 00:00:00             NaN         NaN           NaN
# 1294  2021-07-01 00:00:00             NaN         NaN           NaN
# 1295  2021-07-01 00:00:00             NaN         NaN           NaN
# 1296  2021-07-01 00:00:00             NaN         NaN           NaN
#
#      Fees Total Fees Pending
# 0          7500            0
# 1          8550            0
# 2          6750            0
# 3          8550            0
# ...

# %%
df.isnull().sum()
# Out:
# Month              100
# Counsellor Name    158
# Course Name        397
# Fees Received      151
# Fees Total         158
# Fees Pending       205
# dtype: int64

# %%
df.dropna(subset=['Fees Received'],inplace=True)
df
# Out:
#                     Month Counsellor Name Course Name Fees Received  \
# 0     2020-04-01 00:00:00           Pooja         NaN          7500
# 1     2020-04-01 00:00:00          Deepak         NaN          8550
# 2     2020-04-01 00:00:00           Pooja         NaN          6750
# 3     2020-04-01 00:00:00          Deepak         NaN          8550
# 4     2020-04-01 00:00:00          Deepak         NaN          5000
# ...                   ...             ...         ...           ...
# 1286  2021-07-01 00:00:00             NaN         NaN          5000
# 1287  2021-07-01 00:00:00             NaN         NaN         22500
# 1288  2021-07-01 00:00:00             NaN         NaN         20650
# 1289  2021-07-01 00:00:00             NaN         NaN         20600
# 1290  2021-07-01 00:00:00             NaN         NaN          5000
#
#      Fees Total Fees Pending
# 0          7500            0
# 1          8550            0
# 2          6750            0
# 3          8550            0
# ...

# %%
df.isnull().sum()
# Out:
# Month                2
# Counsellor Name      7
# Course Name        248
# Fees Received        0
# Fees Total           7
# Fees Pending        93
# dtype: int64

# %%
IsDigit=pd.DataFrame(df['Fees Received'].str.isdigit())
notDigit=df[IsDigit['Fees Received']==False]
notDigit
# Out:
#       Month Counsellor Name               Course Name  Fees Received  \
# 52    Month           Owner  Certifiacte Print Status  Fees Received
# 108   Month           Owner               Designation  Fees Received
# 161   Month           Owner               Designation  Fees Received
# 193   Month           Owner               Designation  Fees Received
# 255   Month           Owner                Batch Date  Fees Received
# 302   Month           Owner                Batch Date  Fees Received
# 354   Month           Owner                    Course  Fees Received
# 420   Month           Owner                    Course  Fees Received
# 559   Month           Owner                    Course  Fees Received
# 650   Month           Owner                    Course  Fees Received
# 744   Month           Owner                    Course  Fees Received
# 826   Month           Owner                    Course  Fees Received
# 958   Month           Owner                    Course  Fees Received
# ...

# %%
df.drop(notDigit.index,inplace=True)
df
# Out:
#                     Month Counsellor Name Course Name Fees Received  \
# 0     2020-04-01 00:00:00           Pooja         NaN          7500
# 1     2020-04-01 00:00:00          Deepak         NaN          8550
# 2     2020-04-01 00:00:00           Pooja         NaN          6750
# 3     2020-04-01 00:00:00          Deepak         NaN          8550
# 4     2020-04-01 00:00:00          Deepak         NaN          5000
# ...                   ...             ...         ...           ...
# 1286  2021-07-01 00:00:00             NaN         NaN          5000
# 1287  2021-07-01 00:00:00             NaN         NaN         22500
# 1288  2021-07-01 00:00:00             NaN         NaN         20650
# 1289  2021-07-01 00:00:00             NaN         NaN         20600
# 1290  2021-07-01 00:00:00             NaN         NaN          5000
#
#      Fees Total Fees Pending
# 0          7500            0
# 1          8550            0
# 2          6750            0
# 3          8550            0
# ...

# %%
df.isnull().sum()
# Out:
# Month                2
# Counsellor Name      7
# Course Name        248
# Fees Received        0
# Fees Total           7
# Fees Pending        93
# dtype: int64

# %%
df.dtypes
# Out:
# Month              object
# Counsellor Name    object
# Course Name        object
# Fees Received      object
# Fees Total         object
# Fees Pending       object
# dtype: object

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#                     Month Counsellor Name Course Name Fees Received  \
# 0     2020-04-01 00:00:00           Pooja         NaN          7500
# 1     2020-04-01 00:00:00          Deepak         NaN          8550
# 2     2020-04-01 00:00:00           Pooja         NaN          6750
# 3     2020-04-01 00:00:00          Deepak         NaN          8550
# 4     2020-04-01 00:00:00          Deepak         NaN          5000
# ...                   ...             ...         ...           ...
# 1127  2021-07-01 00:00:00             NaN         NaN          5000
# 1128  2021-07-01 00:00:00             NaN         NaN         22500
# 1129  2021-07-01 00:00:00             NaN         NaN         20650
# 1130  2021-07-01 00:00:00             NaN         NaN         20600
# 1131  2021-07-01 00:00:00             NaN         NaN          5000
#
#      Fees Total Fees Pending
# 0          7500            0
# 1          8550            0
# 2          6750            0
# 3          8550            0
# ...

# %%
df[df.isna().any(axis=1)]
# Out:
#                     Month Counsellor Name Course Name Fees Received  \
# 0     2020-04-01 00:00:00           Pooja         NaN          7500
# 1     2020-04-01 00:00:00          Deepak         NaN          8550
# 2     2020-04-01 00:00:00           Pooja         NaN          6750
# 3     2020-04-01 00:00:00          Deepak         NaN          8550
# 4     2020-04-01 00:00:00          Deepak         NaN          5000
# ...                   ...             ...         ...           ...
# 1127  2021-07-01 00:00:00             NaN         NaN          5000
# 1128  2021-07-01 00:00:00             NaN         NaN         22500
# 1129  2021-07-01 00:00:00             NaN         NaN         20650
# 1130  2021-07-01 00:00:00             NaN         NaN         20600
# 1131  2021-07-01 00:00:00             NaN         NaN          5000
#
#      Fees Total Fees Pending
# 0          7500            0
# 1          8550            0
# 2          6750            0
# 3          8550            0
# ...

# %%
df[df['Month'].isna()]
# Out:
#     Month Counsellor Name Course Name Fees Received Fees Total Fees Pending
# 72    NaN           Vikas         NaN          6500       6500            0
# 612   NaN          Poonam         NaN         20650      20650          NaN

# %%
df['Month'].fillna(method='ffill',inplace=True)
df
# Out:
#                     Month Counsellor Name Course Name Fees Received  \
# 0     2020-04-01 00:00:00           Pooja         NaN          7500
# 1     2020-04-01 00:00:00          Deepak         NaN          8550
# 2     2020-04-01 00:00:00           Pooja         NaN          6750
# 3     2020-04-01 00:00:00          Deepak         NaN          8550
# 4     2020-04-01 00:00:00          Deepak         NaN          5000
# ...                   ...             ...         ...           ...
# 1127  2021-07-01 00:00:00             NaN         NaN          5000
# 1128  2021-07-01 00:00:00             NaN         NaN         22500
# 1129  2021-07-01 00:00:00             NaN         NaN         20650
# 1130  2021-07-01 00:00:00             NaN         NaN         20600
# 1131  2021-07-01 00:00:00             NaN         NaN          5000
#
#      Fees Total Fees Pending
# 0          7500            0
# 1          8550            0
# 2          6750            0
# 3          8550            0
# ...

# %%
df.isnull().sum()
# Out:
# Month                0
# Counsellor Name      7
# Course Name        248
# Fees Received        0
# Fees Total           7
# Fees Pending        93
# dtype: int64

# %%
df['Fees Received']=df['Fees Received'].astype('int64')

# %%
res = df[[isinstance(value, int) for value in df['Month']]]
res.Month=np.nan
print(res)
df.drop(res.index,inplace=True)
df = pd.concat([df, res])
df.sort_index(axis=0, ascending=True, inplace=True)
# Out:
#      Month Counsellor Name Course Name  Fees Received Fees Total Fees Pending
# 950    NaN          Varsha        SSBB          17700      17700            0
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df['Month'].fillna(method='ffill',inplace=True)
df
# Out:
#           Month Counsellor Name Course Name  Fees Received Fees Total  \
# 0    2020-04-01           Pooja         NaN           7500       7500
# 1    2020-04-01          Deepak         NaN           8550       8550
# 2    2020-04-01           Pooja         NaN           6750       6750
# 3    2020-04-01          Deepak         NaN           8550       8550
# 4    2020-04-01          Deepak         NaN           5000       5000
# ...         ...             ...         ...            ...        ...
# 1127 2021-07-01             NaN         NaN           5000      18000
# 1128 2021-07-01             NaN         NaN          22500      22500
# 1129 2021-07-01             NaN         NaN          20650      20650
# 1130 2021-07-01             NaN         NaN          20600      20600
# 1131 2021-07-01             NaN         NaN           5000      15000
#
#      Fees Pending
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...

# %%
res = df[[isinstance(value, int) for value in df['Month']]]
res
# Out:
# Empty DataFrame
# Columns: [Month, Counsellor Name, Course Name, Fees Received, Fees Total, Fees Pending]
# Index: []

# %%
df['Month'] = pd.to_datetime(df['Month'])

# %%
df['Course Name'].fillna(value='GST',inplace=True)

# %%
df.dtypes
# Out:
# Month              datetime64[ns]
# Counsellor Name            object
# Course Name                object
# Fees Received               int64
# Fees Total                 object
# Fees Pending               object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Month               0
# Counsellor Name     7
# Course Name         0
# Fees Received       0
# Fees Total          7
# Fees Pending       93
# dtype: int64

# %%
df[df['Counsellor Name'].isna()]
# Out:
#           Month Counsellor Name Course Name  Fees Received Fees Total  \
# 138  2020-07-01             NaN         GST          12500      12500
# 362  2020-12-01             NaN         gst           6000       6000
# 1127 2021-07-01             NaN         GST           5000      18000
# 1128 2021-07-01             NaN         GST          22500      22500
# 1129 2021-07-01             NaN         GST          20650      20650
# 1130 2021-07-01             NaN         GST          20600      20600
# 1131 2021-07-01             NaN         GST           5000      15000
#
#      Fees Pending
# 138           NaN
# 362             0
# 1127        13000
# 1128            0
# 1129            0
# 1130            0
# 1131        10000

# %%
df['Counsellor Name'].fillna(value='No Counsellor',inplace=True)

# %%
empty=df[df['Fees Total'].isna()]
empty
# Out:
#           Month Counsellor Name Course Name  Fees Received Fees Total  \
# 184  2020-08-01           Pooja          Na           9500        NaN
# 255  2020-10-01           Pooja         GST           9500        NaN
# 278  2020-11-01            Anam         GST           5000        NaN
# 378  2020-12-01          Deepak         gst           2000        NaN
# 1058 2021-07-01     Deepak Arya    SAP FICO          25075        NaN
# 1059 2021-07-01     Deepak Arya      SAP HR          20250        NaN
# 1102 2021-07-01     Deepak Arya      SAP MM          23600        NaN
#
#      Fees Pending
# 184           NaN
# 255             0
# 278           NaN
# 378         -2000
# 1058       -25075
# 1059       -20250
# 1102       -23600

# %%
empty['Fees Total'] = empty['Fees Received']
empty
# Out:
# <ipython-input-30-6707c76ac696>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty['Fees Total'] = empty['Fees Received']
#           Month Counsellor Name Course Name  Fees Received  Fees Total  \
# 184  2020-08-01           Pooja          Na           9500        9500
# 255  2020-10-01           Pooja         GST           9500        9500
# 278  2020-11-01            Anam         GST           5000        5000
# 378  2020-12-01          Deepak         gst           2000        2000
# 1058 2021-07-01     Deepak Arya    SAP FICO          25075       25075
# 1059 2021-07-01     Deepak Arya      SAP HR          20250       20250
# 1102 2021-07-01     Deepak Arya      SAP MM          23600       23600
#
#      Fees Pending
# ...

# %%
df.drop(empty.index,inplace=True)
df
# Out:
#           Month Counsellor Name Course Name  Fees Received Fees Total  \
# 0    2020-04-01           Pooja         GST           7500       7500
# 1    2020-04-01          Deepak         GST           8550       8550
# 2    2020-04-01           Pooja         GST           6750       6750
# 3    2020-04-01          Deepak         GST           8550       8550
# 4    2020-04-01          Deepak         GST           5000       5000
# ...         ...             ...         ...            ...        ...
# 1127 2021-07-01   No Counsellor         GST           5000      18000
# 1128 2021-07-01   No Counsellor         GST          22500      22500
# 1129 2021-07-01   No Counsellor         GST          20650      20650
# 1130 2021-07-01   No Counsellor         GST          20600      20600
# 1131 2021-07-01   No Counsellor         GST           5000      15000
#
#      Fees Pending
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...

# %%
df = pd.concat([df, empty])
df
# Out:
#           Month Counsellor Name Course Name  Fees Received Fees Total  \
# 0    2020-04-01           Pooja         GST           7500       7500
# 1    2020-04-01          Deepak         GST           8550       8550
# 2    2020-04-01           Pooja         GST           6750       6750
# 3    2020-04-01          Deepak         GST           8550       8550
# 4    2020-04-01          Deepak         GST           5000       5000
# ...         ...             ...         ...            ...        ...
# 278  2020-11-01            Anam         GST           5000       5000
# 378  2020-12-01          Deepak         gst           2000       2000
# 1058 2021-07-01     Deepak Arya    SAP FICO          25075      25075
# 1059 2021-07-01     Deepak Arya      SAP HR          20250      20250
# 1102 2021-07-01     Deepak Arya      SAP MM          23600      23600
#
#      Fees Pending
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...

# %%
df.sort_index(axis=0, ascending=True, inplace=True)
df
# Out:
#           Month Counsellor Name Course Name  Fees Received Fees Total  \
# 0    2020-04-01           Pooja         GST           7500       7500
# 1    2020-04-01          Deepak         GST           8550       8550
# 2    2020-04-01           Pooja         GST           6750       6750
# 3    2020-04-01          Deepak         GST           8550       8550
# 4    2020-04-01          Deepak         GST           5000       5000
# ...         ...             ...         ...            ...        ...
# 1127 2021-07-01   No Counsellor         GST           5000      18000
# 1128 2021-07-01   No Counsellor         GST          22500      22500
# 1129 2021-07-01   No Counsellor         GST          20650      20650
# 1130 2021-07-01   No Counsellor         GST          20600      20600
# 1131 2021-07-01   No Counsellor         GST           5000      15000
#
#      Fees Pending
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...

# %%
df['Fees Total']=df['Fees Total'].astype('int64')

# %%
df['FeesPending'] = df['Fees Total'] - df['Fees Received']
df
# Out:
#           Month Counsellor Name Course Name  Fees Received  Fees Total  \
# 0    2020-04-01           Pooja         GST           7500        7500
# 1    2020-04-01          Deepak         GST           8550        8550
# 2    2020-04-01           Pooja         GST           6750        6750
# 3    2020-04-01          Deepak         GST           8550        8550
# 4    2020-04-01          Deepak         GST           5000        5000
# ...         ...             ...         ...            ...         ...
# 1127 2021-07-01   No Counsellor         GST           5000       18000
# 1128 2021-07-01   No Counsellor         GST          22500       22500
# 1129 2021-07-01   No Counsellor         GST          20650       20650
# 1130 2021-07-01   No Counsellor         GST          20600       20600
# 1131 2021-07-01   No Counsellor         GST           5000       15000
#
#      Fees Pending  FeesPending
# 0               0            0
# 1               0            0
# ...

# %%
df.drop(['Fees Pending'],axis=1,inplace=True)
df
# Out:
#           Month Counsellor Name Course Name  Fees Received  Fees Total  \
# 0    2020-04-01           Pooja         GST           7500        7500
# 1    2020-04-01          Deepak         GST           8550        8550
# 2    2020-04-01           Pooja         GST           6750        6750
# 3    2020-04-01          Deepak         GST           8550        8550
# 4    2020-04-01          Deepak         GST           5000        5000
# ...         ...             ...         ...            ...         ...
# 1127 2021-07-01   No Counsellor         GST           5000       18000
# 1128 2021-07-01   No Counsellor         GST          22500       22500
# 1129 2021-07-01   No Counsellor         GST          20650       20650
# 1130 2021-07-01   No Counsellor         GST          20600       20600
# 1131 2021-07-01   No Counsellor         GST           5000       15000
#
#       FeesPending
# 0               0
# 1               0
# 2               0
# 3               0
# ...

# %%
df.isnull().sum()
# Out:
# Month              0
# Counsellor Name    0
# Course Name        0
# Fees Received      0
# Fees Total         0
# FeesPending        0
# dtype: int64

# %%
df.dtypes
# Out:
# Month              datetime64[ns]
# Counsellor Name            object
# Course Name                object
# Fees Received               int64
# Fees Total                  int64
# FeesPending                 int64
# dtype: object

# %%
df.to_excel("GST_cleaned.xlsx")
