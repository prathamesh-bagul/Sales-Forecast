# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('Data Sheet for Interns.xlsx',sheet_name='CDCW',header=1)

# %%
df.shape
# Out:
# (2878, 6)

# %%
df.head()
# Out:
#                  Month Counsellor Name Course Name Fees Total Fees Received  \
# 0                  NaN             NaN         NaN        NaN           NaN
# 1  2020-04-01 00:00:00              SK        CADM       5000          5000
# 2  2020-04-01 00:00:00              SK        CDCW       7500          7500
# 3  2020-04-01 00:00:00              SK        CDCW       9500          9500
# 4  2020-04-01 00:00:00              IJ         NaN       9500          9500
#
#   Fees Pending
# 0          NaN
# 1            0
# 2            0
# 3            0
# 4            0

# %%
df.isnull().sum()
# Out:
# Month              159
# Counsellor Name    339
# Course Name        500
# Fees Total         339
# Fees Received      344
# Fees Pending       320
# dtype: int64

# %%
df.dropna(how='all',inplace=True)
df.isnull().sum()
# Out:
# Month               32
# Counsellor Name    212
# Course Name        373
# Fees Total         212
# Fees Received      217
# Fees Pending       193
# dtype: int64

# %%
df[df['Counsellor Name'].isna()]
# Out:
#                     Month Counsellor Name Course Name Fees Total  \
# 17    2020-04-01 00:00:00             NaN         NaN        NaN
# 168   2020-05-01 00:00:00             NaN         NaN        NaN
# 193   2020-05-01 00:00:00             NaN         NaN        NaN
# 212   2020-05-01 00:00:00             NaN         NaN        NaN
# 219   2020-05-01 00:00:00             NaN         NaN        NaN
# ...                   ...             ...         ...        ...
# 2873  2021-07-01 00:00:00             NaN         NaN        NaN
# 2874  2021-07-01 00:00:00             NaN         NaN        NaN
# 2875  2021-07-01 00:00:00             NaN         NaN        NaN
# 2876  2021-07-01 00:00:00             NaN         NaN        NaN
# 2877  2021-07-01 00:00:00             NaN         NaN        NaN
#
#      Fees Received Fees Pending
# 17             NaN          NaN
# 168            NaN          NaN
# 193            NaN          NaN
# 212            NaN          NaN
# 219            NaN          NaN
# ...            ...          ...
# 2873           NaN          NaN
# 2874           NaN          NaN
# 2875           NaN          NaN
# 2876           NaN          NaN
# 2877           NaN          NaN
#
# [212 rows x 6 columns]

# %%
df.dropna(subset=['Counsellor Name','Course Name','Fees Received','Fees Total','Fees Pending'],how='all',inplace=True)

# %%
df[df['Counsellor Name'].isna()]
# Out:
#                     Month Counsellor Name Course Name Fees Total  \
# 349   2020-06-01 00:00:00             NaN         NaN        NaN
# 766   2020-08-01 00:00:00             NaN         NaN        NaN
# 767   2020-08-01 00:00:00             NaN         NaN        NaN
# 768   2020-08-01 00:00:00             NaN         NaN        NaN
# 769   2020-08-01 00:00:00             NaN         NaN        NaN
# ...                   ...             ...         ...        ...
# 2593  2021-06-01 00:00:00             NaN         NaN        NaN
# 2760  2021-07-01 00:00:00             NaN        CDCW      12750
# 2763  2021-07-01 00:00:00             NaN         NaN      15000
# 2764  2021-07-01 00:00:00             NaN         NaN      12750
# 2765  2021-07-01 00:00:00             NaN         NaN      39000
#
#      Fees Received Fees Pending
# 349            NaN            0
# 766            NaN            0
# 767            NaN            0
# 768            NaN            0
# 769            NaN            0
# ...            ...          ...
# 2593           NaN            0
# 2760         12750            0
# 2763         15000            0
# 2764         12750            0
# 2765         15000        24000
#
# [64 rows x 6 columns]

# %%
df.dropna(subset=['Counsellor Name','Course Name','Fees Received','Fees Total'],how='all',inplace=True)
df[df['Counsellor Name'].isna()]
# Out:
#                     Month Counsellor Name Course Name Fees Total  \
# 1005                  NaN             NaN        CDCW        NaN
# 2760  2021-07-01 00:00:00             NaN        CDCW      12750
# 2763  2021-07-01 00:00:00             NaN         NaN      15000
# 2764  2021-07-01 00:00:00             NaN         NaN      12750
# 2765  2021-07-01 00:00:00             NaN         NaN      39000
#
#      Fees Received Fees Pending
# 1005           NaN            0
# 2760         12750            0
# 2763         15000            0
# 2764         12750            0
# 2765         15000        24000

# %%
df.isnull().sum()
# Out:
# Month                4
# Counsellor Name      5
# Course Name        166
# Fees Total           5
# Fees Received       10
# Fees Pending        45
# dtype: int64

# %%
df[df['Fees Received'].isna()]
# Out:
#                     Month Counsellor Name       Course Name  \
# 51    2020-04-01 00:00:00              NK               NaN
# 52    2020-04-01 00:00:00              NK               NaN
# 167   2020-05-01 00:00:00              SK              CDCW
# 175   2020-05-01 00:00:00              IJ  Creative Writing
# 177   2020-05-01 00:00:00              IJ  Creative Writing
# 334                   NaN              SK               NaN
# 395   2020-06-01 00:00:00              NK  Technical Writer
# 544   2020-07-01 00:00:00              NC               NaN
# 1005                  NaN             NaN              CDCW
# 1889                  NaN              SS               NaN
#
#                          Fees Total Fees Received Fees Pending
# 51                            13500           NaN          NaN
# 52                            13500           NaN          NaN
# 167                             NaN           NaN          NaN
# 175                priti's daughter           NaN          NaN
# 177   paid by Deepti lamba as combo           NaN          NaN
# 334                             NaN           NaN          NaN
# 395                            6800           NaN         6800
# 544                             NaN           NaN            0
# 1005                            NaN           NaN            0
# 1889                            NaN           NaN            0

# %%
df.dropna(subset=['Fees Received','Fees Pending'],how='all',inplace=True)
df[df['Fees Total'].isna()]
# Out:
#                     Month Counsellor Name Course Name Fees Total  \
# 544   2020-07-01 00:00:00              NC         NaN        NaN
# 1005                  NaN             NaN        CDCW        NaN
# 1889                  NaN              SS         NaN        NaN
#
#      Fees Received Fees Pending
# 544            NaN            0
# 1005           NaN            0
# 1889           NaN            0

# %%
df.dropna(subset=['Fees Received','Fees Total'],how='all',inplace=True)

# %%
df.isnull().sum()
# Out:
# Month                1
# Counsellor Name      4
# Course Name        161
# Fees Total           0
# Fees Received        1
# Fees Pending        39
# dtype: int64

# %%
IsDigit=pd.DataFrame(df['Fees Received'].str.isdigit())
notDigit=df[IsDigit['Fees Received']==False]
notDigit
# Out:
#                     Month     Counsellor Name             Course Name  \
# 12    2020-04-01 00:00:00                  MM                     NaN
# 78    2020-04-01 00:00:00                  MM                     NaN
# 87    2020-04-01 00:00:00  Kunal Sir's friend                     NaN
# 116   2020-04-01 00:00:00                  SK                     NaN
# 117   2020-04-01 00:00:00                  VU                     NaN
# 157                 Month     Counsellor Name             Course Name
# 164   2020-05-01 00:00:00                  MM                    CDCW
# 165   2020-05-01 00:00:00                  MM                    CDCW
# 183   2020-05-01 00:00:00                  VU                     NaN
# 200   2020-05-01 00:00:00                  NK                    CDCW
# 201   2020-05-01 00:00:00                  SK                     NaN
# 202   2020-05-01 00:00:00                  NK                     NaN
# 215   2020-05-01 00:00:00                  NK                    CADM
# 217   2020-05-01 00:00:00                  MM                    CADM
# 275   2020-05-01 00:00:00                  MM                    CDCW
# 297   2020-05-01 00:00:00                  SK                    CDCW
# 333                  megh     Counsellor Name             Course Name
# 364   2020-06-01 00:00:00                  SK                    CDCW
# 431   2020-06-01 00:00:00                  MM                    CDCW
# 487                   NaN     Counsellor Name             Course Name
# 498   2020-07-01 00:00:00                  SS                    CDCW
# 519   2020-07-01 00:00:00                  MM                    CDCW
# 520   2020-07-01 00:00:00                  NK  CDCW+Creative Writting
# 540   2020-07-01 00:00:00                  NK  CDCW+Creative Writting
# 624                 Month     Counsellor Name             Course Name
# 686   2020-08-01 00:00:00                  SK                     NaN
# 688   2020-08-01 00:00:00                  SK                     NaN
# 689   2020-08-01 00:00:00                  SK                     NaN
# 709   2020-08-01 00:00:00                  NK  CDCW+Creative Writting
# 774                 Month     Counsellor Name             Course Name
# 800   2020-09-01 00:00:00                  SK                     NaN
# 818   2020-09-01 00:00:00                  NK                    CDCW
# 820   2020-09-01 00:00:00                  SK               CDCW+CADM
# 840   2020-09-01 00:00:00                  NK       Creative Writting
# 883                 Month     Counsellor Name             Course Name
# 964   2020-10-01 00:00:00                  SS                    CDCW
# 1013  2020-10-01 00:00:00                  SS                    CDCW
# 1022                Month     Counsellor Name             Course Name
# 1179                Month     Counsellor Name             Course Name
# 1186  2020-12-01 00:00:00                  SS       Creative Writting
# 1187  2020-12-01 00:00:00                  SS        Technical Writer
# 1200  2020-12-01 00:00:00                  SS        Creative writing
# 1357  2020-12-01 00:00:00                  NK                    CDCW
# 1358  2020-12-01 00:00:00                  NK                    CDCW
# 1359  2020-12-01 00:00:00                  NK                    CDCW
# 1360  2020-12-01 00:00:00                  NK                    CDCW
# 1361  2020-12-01 00:00:00                  NK                    CDCW
# 1368                Month     Counsellor Name             Course Name
# 1525                Month     Counsellor Name             Course Name
# 1676                Month     Counsellor Name             Course Name
# 1897                Month     Counsellor Name             Course Name
# 2074                Month     Counsellor Name             Course Name
# 2355                Month     Counsellor Name             Course Name
# 2599                Month     Counsellor Name             Course Name
#
#               Fees Total       Fees Received     Fees Pending
# 12         Carry forward       Carry forward              NaN
# 78         Carry forward       Carry forward              NaN
# 87    Kunal Sir's friend  Kunal Sir's friend              NaN
# 116        Carry Forward       Carry Forward              NaN
# 117        Carry Forward       Carry Forward              NaN
# 157           Fees Total       Fees Received     Fees Pending
# 164        carry forward       carry forward    carry forward
# 165        carry forward       carry forward    carry forward
# 183        CARRY FORWARD       CARRY FORWARD    CARRY FORWARD
# 200           CARRY FORW          CARRY FORW       CARRY FORW
# 201           CARRY FORW          CARRY FORW                0
# 202           CARRY FORW          CARRY FORW              NaN
# 215           CARRY FORW          CARRY FORW       CARRY FORW
# 217           CARRY FORW          CARRY FORW       CARRY FORW
# 275      Carry Forwarded     Carry Forwarded              NaN
# 297        Carry Forward       Carry Forward              NaN
# 333           Fees Total       Fees Received     Fees Pending
# 364        Carry Forward       Carry Forward              NaN
# 431      Carry forwarded     Carry forwarded  Carry forwarded
# 487           Fees Total       Fees Received     Fees Pending
# 498        Carry forward       Carry forward              NaN
# 519        Carry forward       Carry forward              NaN
# 520        Carry forward       Carry forward              NaN
# 540        carry forward       carry forward              NaN
# 624           Fees Total       Fees Received     Fees Pending
# 686        Carry Forward       Carry Forward              NaN
# 688        Carry Forward       Carry Forward              NaN
# 689        Carry Forward       Carry Forward              NaN
# 709        carry forward       carry forward              NaN
# 774           Fees Total       Fees Received     Fees Pending
# 800        carry forward       carry forward              NaN
# 818        Carry forward       Carry forward              NaN
# 820        Carry forward       Carry Forward              NaN
# 840        Carry Forward       Carry Forward              NaN
# 883           Fees Total       Fees Received     Fees Pending
# 964        Carry forward       Carry forward              NaN
# 1013       Carry Forward       Carry Forward              NaN
# 1022          Fees Total       Fees Received     Fees Pending
# 1179          Fees Total       Fees Received     Fees Pending
# 1186       Carry Forward       Carry Forward              NaN
# 1187       Carry Forward       Carry Forward              NaN
# 1200       Carry forward       Carry forward              NaN
# 1357     Corporate Batch     Corporate Batch  Corporate Batch
# 1358     Corporate Batch     Corporate Batch  Corporate Batch
# 1359     Corporate Batch     Corporate Batch  Corporate Batch
# 1360     Corporate Batch     Corporate Batch  Corporate Batch
# 1361     Corporate Batch     Corporate Batch  Corporate Batch
# 1368          Fees Total       Fees Received     Fees Pending
# 1525          Fees Total       Fees Received     Fees Pending
# 1676          Fees Total       Fees Received     Fees Pending
# 1897          Fees Total       Fees Received     Fees Pending
# 2074          Fees Total       Fees Received     Fees Pending
# 2355          Fees Total       Fees Received     Fees Pending
# 2599          Fees Total       Fees Received     Fees Pending

# %%
df.drop(notDigit.index,inplace=True)
df
# Out:
#                     Month Counsellor Name    Course Name Fees Total  \
# 1     2020-04-01 00:00:00              SK           CADM       5000
# 2     2020-04-01 00:00:00              SK           CDCW       7500
# 3     2020-04-01 00:00:00              SK           CDCW       9500
# 4     2020-04-01 00:00:00              IJ            NaN       9500
# 5     2020-04-01 00:00:00              NC            NaN       6000
# ...                   ...             ...            ...        ...
# 2761  2021-07-01 00:00:00         Namarta  CDCW+Creative      20000
# 2762  2021-07-01 00:00:00        Mehjabee           CDCW      13500
# 2763  2021-07-01 00:00:00             NaN            NaN      15000
# 2764  2021-07-01 00:00:00             NaN            NaN      12750
# 2765  2021-07-01 00:00:00             NaN            NaN      39000
#
#      Fees Received Fees Pending
# 1             5000            0
# 2             7500            0
# 3             9500            0
# 4             9500            0
# 5             6000            0
# ...            ...          ...
# 2761         15000         5000
# 2762         13500            0
# 2763         15000            0
# 2764         12750            0
# 2765         15000        24000
#
# [2481 rows x 6 columns]

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#                     Month Counsellor Name    Course Name Fees Total  \
# 0     2020-04-01 00:00:00              SK           CADM       5000
# 1     2020-04-01 00:00:00              SK           CDCW       7500
# 2     2020-04-01 00:00:00              SK           CDCW       9500
# 3     2020-04-01 00:00:00              IJ            NaN       9500
# 4     2020-04-01 00:00:00              NC            NaN       6000
# ...                   ...             ...            ...        ...
# 2476  2021-07-01 00:00:00         Namarta  CDCW+Creative      20000
# 2477  2021-07-01 00:00:00        Mehjabee           CDCW      13500
# 2478  2021-07-01 00:00:00             NaN            NaN      15000
# 2479  2021-07-01 00:00:00             NaN            NaN      12750
# 2480  2021-07-01 00:00:00             NaN            NaN      39000
#
#      Fees Received Fees Pending
# 0             5000            0
# 1             7500            0
# 2             9500            0
# 3             9500            0
# 4             6000            0
# ...            ...          ...
# 2476         15000         5000
# 2477         13500            0
# 2478         15000            0
# 2479         12750            0
# 2480         15000        24000
#
# [2481 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Month                0
# Counsellor Name      4
# Course Name        149
# Fees Total           0
# Fees Received        1
# Fees Pending        13
# dtype: int64

# %%
df[df['Counsellor Name'].isna()]
# Out:
#                     Month Counsellor Name Course Name Fees Total  \
# 2475  2021-07-01 00:00:00             NaN        CDCW      12750
# 2478  2021-07-01 00:00:00             NaN         NaN      15000
# 2479  2021-07-01 00:00:00             NaN         NaN      12750
# 2480  2021-07-01 00:00:00             NaN         NaN      39000
#
#      Fees Received Fees Pending
# 2475         12750            0
# 2478         15000            0
# 2479         12750            0
# 2480         15000        24000

# %%
df['Counsellor Name'].fillna(value='No Counsellor',inplace=True)

# %%
df.isnull().sum()
# Out:
# Month                0
# Counsellor Name      0
# Course Name        149
# Fees Total           0
# Fees Received        1
# Fees Pending        13
# dtype: int64

# %%
df[df['Course Name'].isna()]
# Out:
#                     Month Counsellor Name Course Name Fees Total  \
# 3     2020-04-01 00:00:00              IJ         NaN       9500
# 4     2020-04-01 00:00:00              NC         NaN       6000
# 5     2020-04-01 00:00:00              IJ         NaN       8500
# 6     2020-04-01 00:00:00              MM         NaN       7500
# 9     2020-04-01 00:00:00              IJ         NaN       7500
# ...                   ...             ...         ...        ...
# 2461  2021-07-01 00:00:00          Minali         NaN      12000
# 2472  2021-07-01 00:00:00          Minali         NaN      12000
# 2478  2021-07-01 00:00:00   No Counsellor         NaN      15000
# 2479  2021-07-01 00:00:00   No Counsellor         NaN      12750
# 2480  2021-07-01 00:00:00   No Counsellor         NaN      39000
#
#      Fees Received Fees Pending
# 3             9500            0
# 4             6000            0
# 5             8500            0
# 6             7500            0
# 9             7500            0
# ...            ...          ...
# 2461          3000         9000
# 2472         12000            0
# 2478         15000            0
# 2479         12750            0
# 2480         15000        24000
#
# [149 rows x 6 columns]

# %%
df['Course Name'].fillna(value='CDCW',inplace=True)

# %%
df.isnull().sum()
# Out:
# Month               0
# Counsellor Name     0
# Course Name         0
# Fees Total          0
# Fees Received       1
# Fees Pending       13
# dtype: int64

# %%
fees=df[df['Fees Received'].isna()]
fees
# Out:
#                    Month Counsellor Name       Course Name Fees Total  \
# 293  2020-06-01 00:00:00              NK  Technical Writer       6800
#
#     Fees Received Fees Pending
# 293           NaN         6800

# %%
fees['Fees Received'] = fees['Fees Total']-fees['Fees Pending']
df.drop(fees.index,inplace=True)
df = pd.concat([df, fees])
df.sort_index(axis=0, ascending=True, inplace=True)
df
# Out:
# <ipython-input-27-be202db06259>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fees['Fees Received'] = fees['Fees Total']-fees['Fees Pending']
#                     Month Counsellor Name    Course Name Fees Total  \
# 0     2020-04-01 00:00:00              SK           CADM       5000
# 1     2020-04-01 00:00:00              SK           CDCW       7500
# 2     2020-04-01 00:00:00              SK           CDCW       9500
# 3     2020-04-01 00:00:00              IJ           CDCW       9500
# 4     2020-04-01 00:00:00              NC           CDCW       6000
# ...                   ...             ...            ...        ...
# 2476  2021-07-01 00:00:00         Namarta  CDCW+Creative      20000
# 2477  2021-07-01 00:00:00        Mehjabee           CDCW      13500
# 2478  2021-07-01 00:00:00   No Counsellor           CDCW      15000
# 2479  2021-07-01 00:00:00   No Counsellor           CDCW      12750
# 2480  2021-07-01 00:00:00   No Counsellor           CDCW      39000
#
#      Fees Received Fees Pending
# 0             5000            0
# 1             7500            0
# 2             9500            0
# 3             9500            0
# 4             6000            0
# ...            ...          ...
# 2476         15000         5000
# 2477         13500            0
# 2478         15000            0
# 2479         12750            0
# 2480         15000        24000
#
# [2481 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Month               0
# Counsellor Name     0
# Course Name         0
# Fees Total          0
# Fees Received       0
# Fees Pending       13
# dtype: int64

# %%
res = df[[isinstance(value, str) for value in df['Month']]]
res
# Out:
#    Month Counsellor Name Course Name Fees Total Fees Received Fees Pending
# 36     `              NK        CDCW       7000          7000            0

# %%
Month_empty=df[(df.Month=='`')==True]
Month_empty
# Out:
#    Month Counsellor Name Course Name Fees Total Fees Received Fees Pending
# 36     `              NK        CDCW       7000          7000            0

# %%
df['Month'].replace(to_replace=r'`',method='ffill', regex=True,inplace=True)
df
# Out:
#                     Month Counsellor Name    Course Name Fees Total  \
# 0     2020-04-01 00:00:00              SK           CADM       5000
# 1     2020-04-01 00:00:00              SK           CDCW       7500
# 2     2020-04-01 00:00:00              SK           CDCW       9500
# 3     2020-04-01 00:00:00              IJ           CDCW       9500
# 4     2020-04-01 00:00:00              NC           CDCW       6000
# ...                   ...             ...            ...        ...
# 2476  2021-07-01 00:00:00         Namarta  CDCW+Creative      20000
# 2477  2021-07-01 00:00:00        Mehjabee           CDCW      13500
# 2478  2021-07-01 00:00:00   No Counsellor           CDCW      15000
# 2479  2021-07-01 00:00:00   No Counsellor           CDCW      12750
# 2480  2021-07-01 00:00:00   No Counsellor           CDCW      39000
#
#      Fees Received Fees Pending
# 0             5000            0
# 1             7500            0
# 2             9500            0
# 3             9500            0
# 4             6000            0
# ...            ...          ...
# 2476         15000         5000
# 2477         13500            0
# 2478         15000            0
# 2479         12750            0
# 2480         15000        24000
#
# [2481 rows x 6 columns]

# %%
df['Fees Total']=df['Fees Total'].astype('int64')

# %%
df['Fees Received']=df['Fees Received'].astype('int64')

# %%
df.dtypes
# Out:
# Month              object
# Counsellor Name    object
# Course Name        object
# Fees Total          int64
# Fees Received       int64
# Fees Pending       object
# dtype: object

# %%
#df['Month'] = pd.to_datetime(df['Month'])
df['Month']=df['Month'].dt.date
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-0e0a41ae96e6> in <module>
#       1 #df['Month'] = pd.to_datetime(df['Month'])
# ----> 2 df['Month']=df['Month'].dt.date
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
#     182         # https://www.pydanny.com/cached-property.html
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\accessors.py in __new__(cls, data)
#     492             return PeriodProperties(data, orig)
#     493
# --> 494         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
df.reset_index(drop=True,inplace=True)
df

# %%
df.dtypes

# %%
df['FeesPending'] = df['Fees Total'] - df['Fees Received']
df

# %%
df.drop(['Fees Pending'],axis=1,inplace=True)
df

# %%
df.isnull().sum()

# %%
df.dtypes

# %%
df.to_excel("CDCW_cleaned.xlsx")
