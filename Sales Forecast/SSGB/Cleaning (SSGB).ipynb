# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('Data Sheet for Interns.xlsx',sheet_name='SSGB',header=1)

# %%
df.shape
# Out:
# (1613, 6)

# %%
df.head()
# Out:
#   Unnamed: 0 Councellor Name Course Type Fees Received Fees Total Fees Pending
# 0 2020-04-01          Manish    SSGB LVC          5000       5000            0
# 1 2020-04-01          Manish    SSGB LVC          5000       5000            0
# 2 2020-04-01          Manish    SSGB LVC          5000       5000            0
# 3 2020-04-01          Manish    SSGB LVC          5000       5000            0
# 4 2020-04-01          Manish    SSGB LVC          5000       5000            0

# %%
df.rename({'Unnamed: 0': 'Month'}, axis=1, inplace=True)
df.rename({'Councellor Name': 'Counsellor Name'}, axis=1, inplace=True)
df
# Out:
#           Month Counsellor Name Course Type Fees Received Fees Total  \
# 0    2020-04-01          Manish    SSGB LVC          5000       5000
# 1    2020-04-01          Manish    SSGB LVC          5000       5000
# 2    2020-04-01          Manish    SSGB LVC          5000       5000
# 3    2020-04-01          Manish    SSGB LVC          5000       5000
# 4    2020-04-01          Manish    SSGB LVC          5000       5000
# ...         ...             ...         ...           ...        ...
# 1608 2021-07-01           Sonam        SSGB          SSGB      14225
# 1609 2021-07-01          Sonali        SSGB          SSGB      10500
# 1610 2021-07-01             NaN         NaN          SSGB      12250
# 1611 2021-07-01             NaN         NaN          SSGB      17500
# 1612 2021-07-02             NaN         NaN          SSGB      12000
#
#      Fees Pending
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# ...

# %%
df.isnull().sum()
# Out:
# Month               17
# Counsellor Name    152
# Course Type        161
# Fees Received      156
# Fees Total         157
# Fees Pending       191
# dtype: int64

# %%
df.dropna(how='all',inplace=True)

# %%
df.isnull().sum()
# Out:
# Month                0
# Counsellor Name    135
# Course Type        144
# Fees Received      139
# Fees Total         140
# Fees Pending       174
# dtype: int64

# %%
df[df['Counsellor Name'].isna()]
# Out:
#           Month Counsellor Name Course Type Fees Received Fees Total  \
# 56   2020-04-01             NaN         NaN           NaN        NaN
# 57   2020-04-01             NaN         NaN           NaN        NaN
# 58   2020-04-01             NaN         NaN           NaN        NaN
# 59   2020-04-01             NaN         NaN           NaN        NaN
# 60   2020-04-01             NaN         NaN           NaN        NaN
# ...         ...             ...         ...           ...        ...
# 1515 2021-06-01             NaN         NaN           NaN        NaN
# 1557 2021-07-01             NaN         NaN           NaN        NaN
# 1610 2021-07-01             NaN         NaN          SSGB      12250
# 1611 2021-07-01             NaN         NaN          SSGB      17500
# 1612 2021-07-02             NaN         NaN          SSGB      12000
#
#      Fees Pending
# 56            NaN
# 57            NaN
# 58            NaN
# 59            NaN
# 60            NaN
# ...           ...
# ...

# %%
df.dropna(subset=['Counsellor Name','Course Type','Fees Received','Fees Total','Fees Pending'],how='all',inplace=True)

# %%
df.isnull().sum()
# Out:
# Month               0
# Counsellor Name    16
# Course Type        25
# Fees Received      20
# Fees Total         21
# Fees Pending       55
# dtype: int64

# %%
df[df['Counsellor Name'].isna()]
# Out:
#           Month Counsellor Name Course Type Fees Received Fees Total  \
# 63   2020-05-01             NaN         NaN           LVC        NaN
# 158  2020-06-01             NaN         NaN           LVC        NaN
# 423  2020-08-01             NaN         NaN           NaN        NaN
# 562  2020-10-01             NaN         NaN           NaN        NaN
# 798  2020-12-01             NaN         NaN           NaN        NaN
# 799  2020-12-01             NaN         NaN           NaN        NaN
# 800  2020-12-01             NaN         NaN           NaN        NaN
# 808  2021-01-01             NaN         NaN           NaN        NaN
# 867  2021-01-01             NaN         NaN           NaN        NaN
# 975  2021-02-01             NaN         NaN           NaN        NaN
# 976  2021-02-01             NaN         NaN           NaN        NaN
# 1045 2021-03-01             NaN         NaN           NaN        NaN
# 1093 2021-04-01             NaN        SSGB          SSGB          0
# ...

# %%
df=pd.read_excel('SSGB_cleaned Copy.xlsx')

# %%
df
# Out:
#       Unnamed: 0      Month Counsellor Name Course Type Fees Received  \
# 0              0 2020-04-01          Manish    SSGB LVC          5000
# 1              1 2020-04-01          Manish    SSGB LVC          5000
# 2              2 2020-04-01          Manish    SSGB LVC          5000
# 3              3 2020-04-01          Manish    SSGB LVC          5000
# 4              4 2020-04-01          Manish    SSGB LVC          5000
# ...          ...        ...             ...         ...           ...
# 1471        1608 2021-07-01           Sonam        SSGB         14225
# 1472        1609 2021-07-01          Sonali        SSGB         10500
# 1473        1610 2021-07-01             NaN        SSGB         12250
# 1474        1611 2021-07-01             NaN        SSGB         17500
# 1475        1612 2021-07-01             NaN        SSGB         12000
#
#      Fees Total Fees Pending
# 0          5000            0
# 1          5000            0
# 2          5000            0
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Month                0
# Counsellor Name     16
# Course Type         22
# Fees Received       18
# Fees Total          24
# Fees Pending       542
# dtype: int64

# %%
df[df['Counsellor Name'].isna()]
# Out:
#           Month Counsellor Name Course Type Fees Received Fees Total  \
# 56   2020-05-01             NaN         NaN           LVC        NaN
# 140  2020-06-01             NaN         NaN           LVC        NaN
# 381  2020-08-01             NaN         NaN           NaN        NaN
# 507  2020-10-01             NaN         NaN           NaN        NaN
# 717  2020-12-01             NaN         NaN           NaN        NaN
# 718  2020-12-01             NaN         NaN           NaN        NaN
# 719  2020-12-01             NaN         NaN           NaN        NaN
# 723  2021-01-01             NaN         NaN           NaN        NaN
# 782  2021-01-01             NaN         NaN           NaN        NaN
# 879  2021-02-01             NaN         NaN           NaN        NaN
# 880  2021-02-01             NaN         NaN           NaN        NaN
# 946  2021-03-01             NaN         NaN           NaN        NaN
# 985  2021-04-01             NaN        SSGB             0        NaN
# ...

# %%
df.dropna(subset=['Counsellor Name','Course Type','Fees Received','Fees Total'],how='all',inplace=True)
df[df['Counsellor Name'].isna()]
# Out:
#           Month Counsellor Name Course Type Fees Received Fees Total  \
# 56   2020-05-01             NaN         NaN           LVC        NaN
# 140  2020-06-01             NaN         NaN           LVC        NaN
# 985  2021-04-01             NaN        SSGB             0        NaN
# 1473 2021-07-01             NaN        SSGB         12250      12250
# 1474 2021-07-01             NaN        SSGB         17500      17500
# 1475 2021-07-01             NaN        SSGB         12000      12000
#
#      Fees Pending
# 56            NaN
# 140           NaN
# 985           NaN
# 1473          NaN
# 1474          NaN
# 1475          NaN

# %%
df.isnull().sum()
# Out:
# Month                0
# Counsellor Name      6
# Course Type         12
# Fees Received        8
# Fees Total          14
# Fees Pending       542
# dtype: int64

# %%
df[df['Fees Total'].isna()]
# Out:
#           Month Counsellor Name    Course Type Fees Received Fees Total  \
# 56   2020-05-01             NaN            NaN           LVC        NaN
# 140  2020-06-01             NaN            NaN           LVC        NaN
# 178  2020-06-01          Simran       SSGB LVC         12000        NaN
# 319  2020-08-01          Simran            NaN           NaN        NaN
# 353  2020-08-01            Ruby            NaN           NaN        NaN
# 354  2020-08-01            Ruby            NaN           NaN        NaN
# 413  2020-09-01          Simran            NaN           NaN        NaN
# 489  2020-10-01            Ruby           SSGB          8000        NaN
# 975  2021-03-01           Nimra            NaN           NaN        NaN
# 985  2021-04-01             NaN           SSGB             0        NaN
# 989  2021-04-01         Akansha           SSGB          6500        NaN
# 1015 2021-04-01           Sonam  LMS EXtension          1000        NaN
# ...

# %%
df.dropna(subset=['Fees Received','Fees Total'],how='all',inplace=True)
df[df['Fees Total'].isna()]
# Out:
#           Month Counsellor Name    Course Type Fees Received Fees Total  \
# 56   2020-05-01             NaN            NaN           LVC        NaN
# 140  2020-06-01             NaN            NaN           LVC        NaN
# 178  2020-06-01          Simran       SSGB LVC         12000        NaN
# 489  2020-10-01            Ruby           SSGB          8000        NaN
# 985  2021-04-01             NaN           SSGB             0        NaN
# 989  2021-04-01         Akansha           SSGB          6500        NaN
# 1015 2021-04-01           Sonam  LMS EXtension          1000        NaN
#
#      Fees Pending
# 56            NaN
# 140           NaN
# 178           NaN
# 489         -8000
# 985           NaN
# 989           NaN
# 1015          NaN

# %%
df[df['Fees Received'].isna()]
# Out:
#         Month Counsellor Name Course Type Fees Received Fees Total  \
# 58 2020-05-01          Manish    SSGB LVC           NaN      12000
#
#    Fees Pending
# 58          NaN

# %%
df.isnull().sum()
# Out:
# Month                0
# Counsellor Name      6
# Course Type          5
# Fees Received        1
# Fees Total           7
# Fees Pending       540
# dtype: int64

# %%
df.dropna(subset=['Fees Received','Fees Pending'],how='all',inplace=True)
df.isnull().sum()
# Out:
# Month                0
# Counsellor Name      6
# Course Type          5
# Fees Received        0
# Fees Total           7
# Fees Pending       539
# dtype: int64

# %%
IsDigit=pd.DataFrame(df['Fees Received'].str.isdigit())
notDigit=df[IsDigit['Fees Received']==False]
notDigit
# Out:
#           Month  Counsellor Name  Course Type  Fees Received  Fees Total  \
# 56   2020-05-01              NaN          NaN            LVC         NaN
# 57   2020-05-01  CounSellor Name  Course Type  Fees Received  Fees Total
# 140  2020-06-01              NaN          NaN            LVC         NaN
# 141  2020-06-01  Councellor Name  Course Type  Fees Received  Fees Total
# 208  2020-07-01  Councellor Name  Course Type  Fees Received  Fees Total
# 300  2020-08-01       Consultant   Consultant     Consultant  Consultant
# 301  2020-08-01  Councellor Name  Course Type  Fees Received  Fees Total
# 393  2020-09-01       Consultant   Consultant     Consultant  Consultant
# 394  2020-09-01  Councellor Name  Course Type  Fees Received  Fees Total
# 470  2020-10-01       Consultant   Consultant     Consultant  Consultant
# 471  2020-10-01  Councellor Name  Course Type  Fees Received  Fees Total
# 549  2020-11-01       Consultant   Consultant     Consultant  Consultant
# ...

# %%
df.drop(notDigit.index,inplace=True)
df
# Out:
#           Month Counsellor Name Course Type Fees Received Fees Total  \
# 0    2020-04-01          Manish    SSGB LVC          5000       5000
# 1    2020-04-01          Manish    SSGB LVC          5000       5000
# 2    2020-04-01          Manish    SSGB LVC          5000       5000
# 3    2020-04-01          Manish    SSGB LVC          5000       5000
# 4    2020-04-01          Manish    SSGB LVC          5000       5000
# ...         ...             ...         ...           ...        ...
# 1471 2021-07-01           Sonam        SSGB         14225      14225
# 1472 2021-07-01          Sonali        SSGB         10500      10500
# 1473 2021-07-01             NaN        SSGB         12250      12250
# 1474 2021-07-01             NaN        SSGB         17500      17500
# 1475 2021-07-01             NaN        SSGB         12000      12000
#
#      Fees Pending
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# ...

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#           Month Counsellor Name Course Type Fees Received Fees Total  \
# 0    2020-04-01          Manish    SSGB LVC          5000       5000
# 1    2020-04-01          Manish    SSGB LVC          5000       5000
# 2    2020-04-01          Manish    SSGB LVC          5000       5000
# 3    2020-04-01          Manish    SSGB LVC          5000       5000
# 4    2020-04-01          Manish    SSGB LVC          5000       5000
# ...         ...             ...         ...           ...        ...
# 1426 2021-07-01           Sonam        SSGB         14225      14225
# 1427 2021-07-01          Sonali        SSGB         10500      10500
# 1428 2021-07-01             NaN        SSGB         12250      12250
# 1429 2021-07-01             NaN        SSGB         17500      17500
# 1430 2021-07-01             NaN        SSGB         12000      12000
#
#      Fees Pending
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# ...

# %%
df.isnull().sum()
# Out:
# Month                0
# Counsellor Name      4
# Course Type          3
# Fees Received        0
# Fees Total           5
# Fees Pending       531
# dtype: int64

# %%
df[df['Counsellor Name'].isna()]
# Out:
#           Month Counsellor Name Course Type Fees Received Fees Total  \
# 948  2021-04-01             NaN        SSGB             0        NaN
# 1428 2021-07-01             NaN        SSGB         12250      12250
# 1429 2021-07-01             NaN        SSGB         17500      17500
# 1430 2021-07-01             NaN        SSGB         12000      12000
#
#      Fees Pending
# 948           NaN
# 1428          NaN
# 1429          NaN
# 1430          NaN

# %%
df['Counsellor Name'].fillna(value='No Counsellor',inplace=True)

# %%
df.isnull().sum()
# Out:
# Month                0
# Counsellor Name      0
# Course Type          3
# Fees Received        0
# Fees Total           5
# Fees Pending       531
# dtype: int64

# %%
df[df['Course Type'].isna()]
# Out:
#           Month Counsellor Name Course Type Fees Received Fees Total  \
# 326  2020-08-01            Ruby         NaN         11000      11000
# 436  2020-09-01            Ruby         NaN          8000       8000
# 1255 2021-06-01          Manish         NaN          7080       7080
#
#      Fees Pending
# 326             0
# 436             0
# 1255          NaN

# %%
df['Course Type'].fillna(value='SSGB',inplace=True)
df.isnull().sum()
# Out:
# Month                0
# Counsellor Name      0
# Course Type          0
# Fees Received        0
# Fees Total           5
# Fees Pending       531
# dtype: int64

# %%
fees=df[df['Fees Total'].isna()]
fees
# Out:
#          Month Counsellor Name    Course Type Fees Received Fees Total  \
# 173 2020-06-01          Simran       SSGB LVC         12000        NaN
# 472 2020-10-01            Ruby           SSGB          8000        NaN
# 948 2021-04-01   No Counsellor           SSGB             0        NaN
# 952 2021-04-01         Akansha           SSGB          6500        NaN
# 978 2021-04-01           Sonam  LMS EXtension          1000        NaN
#
#     Fees Pending
# 173          NaN
# 472        -8000
# 948          NaN
# 952          NaN
# 978          NaN

# %%
df.drop(949,inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#           Month Counsellor Name Course Type Fees Received Fees Total  \
# 0    2020-04-01          Manish    SSGB LVC          5000       5000
# 1    2020-04-01          Manish    SSGB LVC          5000       5000
# 2    2020-04-01          Manish    SSGB LVC          5000       5000
# 3    2020-04-01          Manish    SSGB LVC          5000       5000
# 4    2020-04-01          Manish    SSGB LVC          5000       5000
# ...         ...             ...         ...           ...        ...
# 1425 2021-07-01           Sonam        SSGB         14225      14225
# 1426 2021-07-01          Sonali        SSGB         10500      10500
# 1427 2021-07-01   No Counsellor        SSGB         12250      12250
# 1428 2021-07-01   No Counsellor        SSGB         17500      17500
# 1429 2021-07-01   No Counsellor        SSGB         12000      12000
#
#      Fees Pending
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# ...

# %%
fees=df[df['Fees Total'].isna()]
fees
# Out:
#          Month Counsellor Name    Course Type Fees Received Fees Total  \
# 173 2020-06-01          Simran       SSGB LVC         12000        NaN
# 472 2020-10-01            Ruby           SSGB          8000        NaN
# 948 2021-04-01   No Counsellor           SSGB             0        NaN
# 951 2021-04-01         Akansha           SSGB          6500        NaN
# 977 2021-04-01           Sonam  LMS EXtension          1000        NaN
#
#     Fees Pending
# 173          NaN
# 472        -8000
# 948          NaN
# 951          NaN
# 977          NaN

# %%
fees['Fees Total'] = fees['Fees Received']
df.drop(fees.index,inplace=True)
df = pd.concat([df, fees])
df.sort_index(axis=0, ascending=True, inplace=True)
df
# Out:
# <ipython-input-37-ee7f80ada3ad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fees['Fees Total'] = fees['Fees Received']
#           Month Counsellor Name Course Type Fees Received Fees Total  \
# 0    2020-04-01          Manish    SSGB LVC          5000       5000
# 1    2020-04-01          Manish    SSGB LVC          5000       5000
# 2    2020-04-01          Manish    SSGB LVC          5000       5000
# 3    2020-04-01          Manish    SSGB LVC          5000       5000
# 4    2020-04-01          Manish    SSGB LVC          5000       5000
# ...         ...             ...         ...           ...        ...
# 1425 2021-07-01           Sonam        SSGB         14225      14225
# ...

# %%
df.isnull().sum()
# Out:
# Month                0
# Counsellor Name      0
# Course Type          0
# Fees Received        0
# Fees Total           0
# Fees Pending       530
# dtype: int64

# %%
res = df[[isinstance(value, str) for value in df['Fees Total']]]
res
# Out:
#          Month Counsellor Name Course Type Fees Received  \
# 495 2020-10-01          Naveen    SSGB LVC          3500
# 496 2020-10-01          Naveen    SSGB LVC          6000
# 954 2021-04-01           Vipin        SSGB         10500
#
#                        Fees Total Fees Pending
# 495    8500 dues clearance simran          NaN
# 496  12000, dues clearance simran          NaN
# 954           sonaltlsn@gmail.com          NaN

# %%
df.drop([496,497],inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#           Month Counsellor Name Course Type Fees Received Fees Total  \
# 0    2020-04-01          Manish    SSGB LVC          5000       5000
# 1    2020-04-01          Manish    SSGB LVC          5000       5000
# 2    2020-04-01          Manish    SSGB LVC          5000       5000
# 3    2020-04-01          Manish    SSGB LVC          5000       5000
# 4    2020-04-01          Manish    SSGB LVC          5000       5000
# ...         ...             ...         ...           ...        ...
# 1423 2021-07-01           Sonam        SSGB         14225      14225
# 1424 2021-07-01          Sonali        SSGB         10500      10500
# 1425 2021-07-01   No Counsellor        SSGB         12250      12250
# 1426 2021-07-01   No Counsellor        SSGB         17500      17500
# 1427 2021-07-01   No Counsellor        SSGB         12000      12000
#
#      Fees Pending
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# ...

# %%
res = df[[isinstance(value, str) for value in df['Fees Total']]]
res
# Out:
#          Month Counsellor Name Course Type Fees Received  \
# 495 2020-10-01          Naveen    SSGB LVC          3500
# 952 2021-04-01           Vipin        SSGB         10500
#
#                      Fees Total Fees Pending
# 495  8500 dues clearance simran          NaN
# 952         sonaltlsn@gmail.com          NaN

# %%
res['Fees Total'] = res['Fees Received']
res
# Out:
# <ipython-input-42-5fb18d929b3c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res['Fees Total'] = res['Fees Received']
#          Month Counsellor Name Course Type Fees Received Fees Total  \
# 495 2020-10-01          Naveen    SSGB LVC          3500       3500
# 952 2021-04-01           Vipin        SSGB         10500      10500
#
#     Fees Pending
# 495          NaN
# 952          NaN

# %%
df.drop(res.index,inplace=True)
df
# Out:
#           Month Counsellor Name Course Type Fees Received Fees Total  \
# 0    2020-04-01          Manish    SSGB LVC          5000       5000
# 1    2020-04-01          Manish    SSGB LVC          5000       5000
# 2    2020-04-01          Manish    SSGB LVC          5000       5000
# 3    2020-04-01          Manish    SSGB LVC          5000       5000
# 4    2020-04-01          Manish    SSGB LVC          5000       5000
# ...         ...             ...         ...           ...        ...
# 1423 2021-07-01           Sonam        SSGB         14225      14225
# 1424 2021-07-01          Sonali        SSGB         10500      10500
# 1425 2021-07-01   No Counsellor        SSGB         12250      12250
# 1426 2021-07-01   No Counsellor        SSGB         17500      17500
# 1427 2021-07-01   No Counsellor        SSGB         12000      12000
#
#      Fees Pending
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# ...

# %%
df = pd.concat([df, res])
df.sort_index(axis=0, ascending=True, inplace=True)
df
# Out:
#           Month Counsellor Name Course Type Fees Received Fees Total  \
# 0    2020-04-01          Manish    SSGB LVC          5000       5000
# 1    2020-04-01          Manish    SSGB LVC          5000       5000
# 2    2020-04-01          Manish    SSGB LVC          5000       5000
# 3    2020-04-01          Manish    SSGB LVC          5000       5000
# 4    2020-04-01          Manish    SSGB LVC          5000       5000
# ...         ...             ...         ...           ...        ...
# 1423 2021-07-01           Sonam        SSGB         14225      14225
# 1424 2021-07-01          Sonali        SSGB         10500      10500
# 1425 2021-07-01   No Counsellor        SSGB         12250      12250
# 1426 2021-07-01   No Counsellor        SSGB         17500      17500
# 1427 2021-07-01   No Counsellor        SSGB         12000      12000
#
#      Fees Pending
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# ...

# %%
res = df[[isinstance(value, str) for value in df['Fees Pending']]]
res
# Out:
#          Month Counsellor Name Course Type Fees Received Fees Total  \
# 394 2020-09-01          Simran    SSGB LVC          5000       8500
# 407 2020-09-01            Ruby    SSGB LVC          6500      10000
# 418 2020-09-01          Simran    SSGB LVC          6000      12000
# 511 2020-10-01          Naveen    SSGB LVC          3500      10000
# 605 2020-12-01           Tarun        SSGB          9000       9000
# 617 2020-12-01           Tarun        SSGB          7500       7500
#
#                                   Fees Pending
# 394  dues cleared in oct by naveen, coloumn 43
# 407         Dues cleared by Naveen in Oct ssgb
# 418  dues cleared in OCT by Naveen. coloumn 44
# 511      0,   DUES CLEARED OF RUBY MAAM CLIENT
# 605                                Due Cleared
# 617                                Due Cleared

# %%
res['Fees Received'] = res['Fees Total']
df.drop(res.index,inplace=True)
df = pd.concat([df, res])
df.sort_index(axis=0, ascending=True, inplace=True)
df
# Out:
# <ipython-input-46-95b06e2a7909>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res['Fees Received'] = res['Fees Total']
#           Month Counsellor Name Course Type Fees Received Fees Total  \
# 0    2020-04-01          Manish    SSGB LVC          5000       5000
# 1    2020-04-01          Manish    SSGB LVC          5000       5000
# 2    2020-04-01          Manish    SSGB LVC          5000       5000
# 3    2020-04-01          Manish    SSGB LVC          5000       5000
# 4    2020-04-01          Manish    SSGB LVC          5000       5000
# ...         ...             ...         ...           ...        ...
# 1423 2021-07-01           Sonam        SSGB         14225      14225
# ...

# %%
res = df[[isinstance(value, str) for value in df['Fees Pending']]]
res
# Out:
#          Month Counsellor Name Course Type Fees Received Fees Total  \
# 394 2020-09-01          Simran    SSGB LVC          8500       8500
# 407 2020-09-01            Ruby    SSGB LVC         10000      10000
# 418 2020-09-01          Simran    SSGB LVC         12000      12000
# 511 2020-10-01          Naveen    SSGB LVC         10000      10000
# 605 2020-12-01           Tarun        SSGB          9000       9000
# 617 2020-12-01           Tarun        SSGB          7500       7500
#
#                                   Fees Pending
# 394  dues cleared in oct by naveen, coloumn 43
# 407         Dues cleared by Naveen in Oct ssgb
# 418  dues cleared in OCT by Naveen. coloumn 44
# 511      0,   DUES CLEARED OF RUBY MAAM CLIENT
# 605                                Due Cleared
# 617                                Due Cleared

# %%
df['Fees Received']=df['Fees Received'].astype('int64')

# %%
df['Fees Total']=df['Fees Total'].astype('int64')

# %%
df['FeesPending'] = df['Fees Total'] - df['Fees Received']
df
# Out:
#           Month Counsellor Name Course Type  Fees Received  Fees Total  \
# 0    2020-04-01          Manish    SSGB LVC           5000        5000
# 1    2020-04-01          Manish    SSGB LVC           5000        5000
# 2    2020-04-01          Manish    SSGB LVC           5000        5000
# 3    2020-04-01          Manish    SSGB LVC           5000        5000
# 4    2020-04-01          Manish    SSGB LVC           5000        5000
# ...         ...             ...         ...            ...         ...
# 1423 2021-07-01           Sonam        SSGB          14225       14225
# 1424 2021-07-01          Sonali        SSGB          10500       10500
# 1425 2021-07-01   No Counsellor        SSGB          12250       12250
# 1426 2021-07-01   No Counsellor        SSGB          17500       17500
# 1427 2021-07-01   No Counsellor        SSGB          12000       12000
#
#      Fees Pending  FeesPending
# 0               0            0
# 1               0            0
# ...

# %%
df.drop(['Fees Pending'],axis=1,inplace=True)
df
# Out:
#           Month Counsellor Name Course Type  Fees Received  Fees Total  \
# 0    2020-04-01          Manish    SSGB LVC           5000        5000
# 1    2020-04-01          Manish    SSGB LVC           5000        5000
# 2    2020-04-01          Manish    SSGB LVC           5000        5000
# 3    2020-04-01          Manish    SSGB LVC           5000        5000
# 4    2020-04-01          Manish    SSGB LVC           5000        5000
# ...         ...             ...         ...            ...         ...
# 1423 2021-07-01           Sonam        SSGB          14225       14225
# 1424 2021-07-01          Sonali        SSGB          10500       10500
# 1425 2021-07-01   No Counsellor        SSGB          12250       12250
# 1426 2021-07-01   No Counsellor        SSGB          17500       17500
# 1427 2021-07-01   No Counsellor        SSGB          12000       12000
#
#       FeesPending
# 0               0
# 1               0
# 2               0
# 3               0
# ...

# %%
df.isnull().sum()
# Out:
# Month              0
# Counsellor Name    0
# Course Type        0
# Fees Received      0
# Fees Total         0
# FeesPending        0
# dtype: int64

# %%
df['Month'] = pd.to_datetime(df['Month'])

# %%
# Z score
from scipy import stats
import numpy as np

z = np.abs(stats.zscore(df['Fees Total']))
print(z)
# Out:
# [1.76448582 1.76448582 1.76448582 ... 0.03089395 1.33099655 0.03101569]

# %%
threshold = 6

# Position of the outlier
print(np.where(z > threshold))
# Out:
# (array([ 616, 1193], dtype=int64),)

# %%
df.dtypes
# Out:
# Month              datetime64[ns]
# Counsellor Name            object
# Course Type                object
# Fees Received               int64
# Fees Total                  int64
# FeesPending                 int64
# dtype: object

# %%
df.to_excel("SSGB_cleaned.xlsx")
